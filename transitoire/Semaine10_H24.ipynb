# %%
import numpy as np
import matplotlib.pyplot as plt
from VFClass_cours10 import VF_1D

# %% [markdown]
# # Cas 1

# %%
fig, ax = plt.subplots()
ax.set_ylim(90,275)
ax.set_xlabel('x (m)')
ax.set_ylabel('T (°C)')

# variables connues
k = 0.5
qG = 1000e3
TA, TB = 100, 200

# ------------------- initialization du cas, 5 VCs --------------------------
# VC = Volume de contrôle
cas1 = VF_1D(L = 2e-2, N_vol = 5)

# créer des éléments i dans les matrices A et D

# conditions aux limites


# résoudre pour T


# tracer T en fonction de x


# ----------------------------------------------------------------------------
# ----------------------------------------------------------------------------
# ------------------- initialization du cas, 100 VCs --------------------------
cas1 = VF_1D(L = 2e-2, N_vol = 100)

# créer des éléments i dans les matrices A et D


# conditions aux limites


# résoudre pour T


# tracer T en fonction de x

# %% [markdown]
# # Cas 2

# %%
fig, ax = plt.subplots()
ax.set_xlabel('x (m)')
ax.set_ylabel('T (°C)')
ax.set_ylim(100,400)

# variables connues
u = 0.01
rho = 1
cp = 100
k = 0.03
alpha = k/(rho*cp)
TA, TB = 300, 100
# ----------------------------------------------
# schema central -------------------------------
# ----------------------------------------------

cas2 = VF_1D(L = 1, N_vol = 500)

# créer des éléments i dans les matrices A et D

# conditions aux limites

# résoudre pour T

# tracer T en fonction de x

# %%
fig, ax = plt.subplots()
ax.set_xlabel('x (m)')
ax.set_ylabel('T (°C)')

# variables connues
u = 0.01
rho = 1
cp = 100
k = 0.03
alpha = k/(rho*cp)
TA, TB = 300, 100
# ----------------------------------------------
# schema upwind -------------------------------
# ----------------------------------------------

cas2 = VF_1D(L = 1, N_vol = 500)

# créer des éléments i dans les matrices A et D

# conditions aux limites

# résoudre pour T


# tracer T en fonction de x

# %% [markdown]
# # Cas 3

# %%
Tx0 = 300
q_xL = 0
u = 2
rho = 1
cp = 100
k = 3e-2
alpha = k / (rho*cp)

fig, ax = plt.subplots(dpi = 100)
# ------------------------------------
cas3 = VF_1D(L = 1, N_vol = 100)
cas3.set_transitoire(t_tot = 0.5, Tini = [100] * cas3.N_vol, dt = 1e-2)
# ------------------------------------







# ------------------------------------
ax.set_xlabel('x (m)')
ax.set_ylabel('T ($^oC$)')
ax.set_ylim(95,305)
# Out:
# (95.0, 305.0)
